# %%
# !pip install pyodbc

# %%
#!pip install pyodbc
import pyodbc
import pandas as pd

# %%
server='10.0.1.40'
database='Ntier_EPIC'
username='Sisenseuser'
password='!w@ntd@t@#123'

# %%
cnxn=pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+password)
cursor=cnxn.cursor()

# %%
query="Select *from [dbo].[vwGenVouchInfo]"
df=pd.read_sql(query,cnxn)

# %%
df
# Out:
#         Voucher_ID  Voucher_Number  Update_Status Voucher_Service_Date  \
# 0                1         4989370              1           2016-10-06
# 1                2         4989400              1           2016-10-06
# 2                3         4989430              1           2016-10-06
# 3                4         4989470              1           2016-10-06
# 4                5         4989500              1           2016-10-06
# ...            ...             ...            ...                  ...
# 605519      625758        13350490              0           2022-02-01
# 605520      625759        13407660              0           2022-02-01
# 605521      625760        13407670              0           2022-02-01
# 605522      625761        13337540              0           2022-01-31
# 605523      625762        13351170              0           2022-02-01
#
#         Claim_Number  Orig_Voucher_Number  Hold_Paper_Claim  \
# ...
